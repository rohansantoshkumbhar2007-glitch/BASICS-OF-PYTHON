# %% [markdown]
# PRACTICAL-3 Study of list and arrays

# %%
#Practical-3
##Study of List and Arrays

# %%
##python lists
thislist=["Mclaren","Redbull","Ferrari"]
print(thislist)
# Out:
# ['Mclaren', 'Redbull', 'Ferrari']

# %%
#Allow Duplicates
thislist=["Mclaren","Redbull","Ferrari","Mclaren","Ferrari"]
print(thislist)
# Out:
# ['Mclaren', 'Redbull', 'Ferrari', 'Mclaren', 'Ferrari']

# %%
#list Length
thislist=["Mclaren","Redbull","Ferrari"]
print(len(thislist))
# Out:
# 3

# %%
#A list with strings,integers and boolean values:
list1=["abc",34,True,"male"]
print(list1)
# Out:
# ['abc', 34, True, 'male']

# %%
#Access Items
thislist=["Mclaren","Redbull","Ferrari"]
print(thislist[1])
# Out:
# Redbull

# %%
#Reverse/negative Indexing
thislist=["Mclaren","Redbull","Ferrari"]
print(thislist[-1])
# Out:
# Ferrari

# %%
#Slicing
thislist=["Mclaren","Redbull","Ferrari","Aston Martin","Mercedes","Audi"]
print(thislist[2:5])
print(thislist[-3:])
print(thislist[-4:])
# Out:
# ['Ferrari', 'Aston Martin', 'Mercedes']
# ['Aston Martin', 'Mercedes', 'Audi']
# ['Ferrari', 'Aston Martin', 'Mercedes', 'Audi']

# %%
#Change Item Value
thislist=["Mclaren","Redbull","Ferrari"]
thislist[1]="Aston Martin"
print(thislist)
# Out:
# ['Mclaren', 'Aston Martin', 'Ferrari']

# %%
#Append Items
thislist=["Mclaren","Redbull","Ferrari"]
thislist.append("Aston Martin")
print(thislist)

# %%
#Insert Items
thislist=["Mclaren","Redbull","Ferrari"]
thislist.insert(2,"Aston Martin")
print(thislist)
